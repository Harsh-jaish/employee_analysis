# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
import warnings
warnings.filterwarnings("ignore") # ignore all the warings along with output

# %%
df=pd.read_csv("/content/people (1) (1).csv")

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
# workAccident
# 0 -  No
# 1 -  Yes

# Left
# 0 - Not in the notice period
# 1 - In the Notice Period ( about leave the complany )

#promotionInLast5years
# 0 - No
# 1 - Yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11991 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfactoryLevel      11991 non-null  float64
#  1   lastEvaluation         11991 non-null  float64
#  2   numberOfProjects       11991 non-null  int64
#  3   avgMonthlyHours        11991 non-null  int64
#  4   timeSpent.company      11991 non-null  int64
#  5   workAccident           11991 non-null  int64
#  6   left                   11991 non-null  int64
#  7   promotionInLast5years  11991 non-null  int64
#  8   dept                   11991 non-null  object
#  9   salary                 11991 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.0+ MB

# %%
df.isnull().sum()
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 3008

# %%
df=df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (11991, 10)

# %%
14999-3008
# Out:
# 11991

# %%
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %% [markdown]
# Does Number of projects effects employee leaving the company

# %%
plt.figure(figsize=(10,4))

sns.countplot(data=df,x="numberOfProjects",hue="left")

plt.show()

# %%
"""
Insights :

If the number of Project is 2 or more than 6, high chance that the employee is going to leave the company

If the number of project is 3 and 4, high chance that employee will stay

Suggestions :

Re-distribute that projects, lessen the number for those having more than 6 and increse for those having less than 3

every employee has to have projects between 3-5
"""
# Out:
# '\nInsights :\n\nIf the number of Project is 2 or more than 6, high chance that the employee is going to leave the company\n\nIf the number of project is 3 and 4, high chance that employee will stay\n\nSuggestions :\n\nRe-distribute that projects, lessen the number for those having more than 6 and increse for those having less than 3\n\nevery employee has to have projects between 3-5\n'

# %% [markdown]
# Does timespent.company ( experince ) effects employee leaving the company

# %%
plt.figure(figsize=(10,4))

ax=sns.countplot(data=df,x="timeSpent.company",hue="left")

ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])

plt.show()


# ax.containers  -- in the given graph it is checking for each container
# bar_label()    -- inbuilt function which will add numbers to each container



"""
for i in ax.containers:
    ax.bar_label(i)
    plt.show()

"""

# %%
# people with the tenure of 3 years are leaving mostly

#Majorly people are leaving having the tenure between 3 & 6 years

# After 6 years people becoming stable and till 3 years as well

#Suggestions:

# People might not getting the growth in 3-5 years of tenure

#Maunal

a=df[df["timeSpent.company"]==4]
a
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 2                   0.11            0.88                 7              272
# 5                   0.10            0.77                 6              247
# 9                   0.11            0.81                 6              305
# 15                  0.11            0.83                 6              282
# 16                  0.09            0.95                 6              304
# ...                  ...             ...               ...              ...
# 14963               0.10            0.93                 6              269
# 14975               0.57            1.00                 3              241
# 14978               0.64            0.50                 3              238
# 14992               0.30            0.88                 5              245
# 14996               0.72            0.72                 4              175
#
# ...

# %%
a["left"].value_counts()
# Out:
# left
# 0    1510
# 1     495
# Name: count, dtype: int64

# %% [markdown]
# Does dept effects employee leaving the company

# %%
plt.figure(figsize=(10,4))

ax=sns.countplot(data=df,x="dept",hue="left")

ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])

plt.show()

# %%
# Sugestions

"""
# people from sales, technical and support departments are leaving more oftenly

# people are leaving might be because of work pressure as in other departments attrition is less

# People from the management are the least in attrition

#Sales employees are leaving mostly

#Next dept is technical and Support who is leaving

#From Management and RandD employees are leaving less

Sugestuins:

# give an option to change the teams within the organizations

# have a meet with those team to undersatnd the issues

# give insentives or some other perks

"""
print()

# %% [markdown]
# Does salary effects employee leaving the company

# %%
plt.figure(figsize=(10,4))

ax=sns.countplot(data=df,x="salary",hue="left")

ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])

plt.show()

# %%
"""
#Insights

#people with the less salary are leaving more oftenly

# people earning moderate salary are comparatively having less attrition rate

# people with higher salary are more stable with the company


#Suggestions:

#appraisals percentage increment
#Right set of employees should be hired for less salary positions with proper expectation settings
#Motivational sessions and growth conselling with internal promotions can bring motivation

They might get better salary or package in other compnay
Suggestion
Salary and park needs to be improve

"""

# %% [markdown]
# Does work accident effects employee leaving the company

# %%
plt.figure(figsize=(10,4))

ax=sns.countplot(data=df,x="workAccident",hue="left")

ax.bar_label(ax.containers[0])
ax.bar_label(ax.containers[1])

plt.show()

# %%
"""
# 0 -- No issues or fights with other emploees
# 1 -- issues or fights with other emploees

# infernce:
 # No actual relation between Work accident and employe leaving the compny.
"""

# %% [markdown]
# Compare Dept wrt. Salary using countplot

# %%
#HW
